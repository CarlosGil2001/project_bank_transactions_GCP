# %%
#!pip install pyspark
#!pip install google-cloud
#!pip install google-cloud-pubsub

# %%
#!wget https://dev.mysql.com/get/Downloads/Connector-J/mysql-connector-java-8.0.27.tar.gz
#!tar -xvzf mysql-connector-java-8.0.27.tar.gz
#!ls mysql-connector-java-8.0.27

# %%
from pyspark import SparkConf, SparkContext, SQLContext
from time import sleep
import os
from google.cloud import pubsub_v1
from google.api_core.exceptions import NotFound
import threading
import json

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'/content/drive/MyDrive/Colab Notebooks/PEA/service-account-admin.json'

# %%
# Var project
project_id = 'ingenieriadatos-392001'

# Var pub/sub
# clientes
topic_id = 'clientes-topic'
subscription_name="clientes-subs"
#transacciones
topic_id_tr = 'transactions-topic'
subscription_name_tr="transactions-topic-subs"

# %%
# Funciones

# Función para que el suscriptor reconozca el mensaje
def callback(message):
    print(f"Mensaje recibido: {message.data}")
    message.ack()  # Confirma el mensaje
    print("Mensaje confirmado.")

# Función para mandar los mensajes de Pub/Sub a Cloud Function
def process_clientes(project_id, topic_id, subscription_name, df=None, batch_size=10):
    publisher = pubsub_v1.PublisherClient() # publicador
    subscriber = pubsub_v1.SubscriberClient() # suscriptor

    topic_path = publisher.topic_path(project_id, topic_id)
    subscription_path = subscriber.subscription_path(project_id, subscription_name)

    # Iniciar la suscripción en un hilo separado
    thread = threading.Thread(target=subscriber.subscribe, args=(subscription_path,), kwargs={"callback": callback}) # confirma los mensajes
    thread.start()

    # Si se proporciona un DataFrame (df), enviar los datos a Pub/Sub en grupos de 10 mensajes
    if df is not None:
        messages = []
        for row in df.collect():
            data = row.asDict()
            messages.append(data)

            if len(messages) >= batch_size:
                for batch_start in range(0, len(messages), batch_size):
                    batch_messages = messages[batch_start:batch_start + batch_size]
                    batch_messages_json = [json.dumps(message) for message in batch_messages]
                    batch_message = "\n".join(batch_messages_json)
                    future = publisher.publish(topic_path, batch_message.encode("utf-8"))
                    sleep(1)
                messages = []

        if messages:
            batch_messages = [json.dumps(message) for message in messages]
            batch_message = "\n".join(batch_messages)
            future = publisher.publish(topic_path, batch_message.encode("utf-8"))

    # Esperar a que el hilo de suscripción termine
    thread.join()

# %%
# Sesión y context Spark
conf = SparkConf().setAppName("AppName").setMaster("local").set("spark.driver.extraClassPath", "/content/mysql-connector-java-8.0.27/mysql-connector-java-8.0.27.jar")
sc = SparkContext.getOrCreate(conf)
spark = SQLContext(sc)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
HOST = '147.182.246.47'
PORT = 3306
USERDB = 'user07'
DATABASE = 'databank'
PASSWORD = 'user07ABC'
URL = f'jdbc:mysql://{HOST}:{PORT}/{DATABASE}'

offset = 0
tam_proceso = 10
max_registros = 50000

while offset < max_registros:
    query = f"(SELECT id, sexo, DATE_FORMAT(fecha_alta, '%d-%m-%Y') as fecha_alta, ingreso, legal_person, age, nivel_educativo FROM clientes WHERE id IN (SELECT id_deposit_client FROM transaction) LIMIT {tam_proceso} OFFSET {offset}) as clientes"
    df_clientes = spark.read.format("jdbc").options(
        url=URL,
        driver="com.mysql.cj.jdbc.Driver",
        dbtable=query,
        user=USERDB,
        password=PASSWORD).load()

    # Si no hay más datos al leer, termina
    if df_clientes.count() == 0:
        break
    # Llamar a la función de Pub/Sub
    process_clientes(project_id, topic_id, subscription_name, df_clientes)
    offset += tam_proceso
    sleep(1)
# Out:
# Mensaje recibido: b'{"id": 445, "sexo": "M", "fecha_alta": "30-08-1973", "ingreso": 0.0, "legal_person": false, "age": 68, "nivel_educativo": "1"}\n{"id": 446, "sexo": "M", "fecha_alta": "10-05-1961", "ingreso": 62.985465079274945, "legal_person": false, "age": 80, "nivel_educativo": "3"}\n{"id": 447, "sexo": "M", "fecha_alta": "16-03-1989", "ingreso": 0.0, "legal_person": false, "age": 52, "nivel_educativo": "3"}\n{"id": 448, "sexo": "M", "fecha_alta": "17-02-1975", "ingreso": 0.0, "legal_person": false, "age": 66, "nivel_educativo": "1"}\n{"id": 449, "sexo": "M", "fecha_alta": "15-06-2011", "ingreso": 5911.784006825921, "legal_person": false, "age": 30, "nivel_educativo": "4"}\n{"id": 450, "sexo": "M", "fecha_alta": "20-08-1981", "ingreso": 384.8085168162185, "legal_person": false, "age": 60, "nivel_educativo": "2"}\n{"id": 1586, "sexo": "M", "fecha_alta": "12-11-2000", "ingreso": 0.0, "legal_person": false, "age": 41, "nivel_educativo": "4"}\n{"id": 1588, "sexo": "M", "fecha_alta": "25-12-1967", "ingreso": 264.27117324254954, "legal_person": false, "age": 74, "nivel_educativo": "3"}\n{"id": 1589, "sexo": "M", "fecha_alta": "26-08-1997", "ingreso": 750.2328237955387, "legal_person": false, "age": 44, "nivel_educativo": "4"}\n{"id": 1593, "sexo": "M", "fecha_alta": "29-04-2022", "ingreso": 0.0, "legal_person": false, "age": 19, "nivel_educativo": "2"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 1594, "sexo": "M", "fecha_alta": "22-08-1998", "ingreso": 1063.3303591003073, "legal_person": false, "age": 43, "nivel_educativo": "3"}\n{"id": 1596, "sexo": "M", "fecha_alta": "16-01-2002", "ingreso": 299.0916703034146, "legal_person": false, "age": 39, "nivel_educativo": "3"}\n{"id": 1598, "sexo": "M", "fecha_alta": "25-02-1967", "ingreso": 1380.655036183248, "legal_person": false, "age": 74, "nivel_educativo": "3"}\n{"id": 1601, "sexo": "M", "fecha_alta": "06-08-1983", "ingreso": 630.9858953585104, "legal_person": false, "age": 58, "nivel_educativo": "2"}\n{"id": 1602, "sexo": "F", "fecha_alta": "18-01-1981", "ingreso": 0.0, "legal_person": false, "age": 60, "nivel_educativo": "2"}\n{"id": 1603, "sexo": "F", "fecha_alta": "19-06-1994", "ingreso": 0.0, "legal_person": false, "age": 47, "nivel_educativo": "1"}\n{"id": 1604, "sexo": "M", "fecha_alta": "03-10-2005", "ingreso": 1445.158674329301, "legal_person": false, "age": 36, "nivel_educativo": "2"}\n{"id": 1605, "sexo": "M", "fecha_alta": "24-12-2021", "ingreso": 287.1545742031784, "legal_person": false, "age": 20, "nivel_educativo": "3"}\n{"id": 1606, "sexo": "F", "fecha_alta": "24-10-2005", "ingreso": 4488.579020189521, "legal_person": false, "age": 36, "nivel_educativo": "3"}\n{"id": 1607, "sexo": "F", "fecha_alta": "12-02-2003", "ingreso": 2215.848815045646, "legal_person": false, "age": 38, "nivel_educativo": "2"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 1611, "sexo": "M", "fecha_alta": "25-06-1972", "ingreso": 2442.9601904945625, "legal_person": false, "age": 69, "nivel_educativo": "1"}\n{"id": 1612, "sexo": "M", "fecha_alta": "25-08-1975", "ingreso": 0.0, "legal_person": false, "age": 66, "nivel_educativo": "3"}\n{"id": 1615, "sexo": "M", "fecha_alta": "01-06-1988", "ingreso": 0.0, "legal_person": false, "age": 53, "nivel_educativo": "3"}\n{"id": 1616, "sexo": "M", "fecha_alta": "18-08-2011", "ingreso": 1856.55, "legal_person": false, "age": 30, "nivel_educativo": "3"}\n{"id": 1617, "sexo": "M", "fecha_alta": "23-01-2006", "ingreso": 3499.5009894631517, "legal_person": false, "age": 35, "nivel_educativo": "3"}\n{"id": 1619, "sexo": "F", "fecha_alta": "12-09-2008", "ingreso": 0.0, "legal_person": false, "age": 33, "nivel_educativo": "2"}\n{"id": 1620, "sexo": "M", "fecha_alta": "20-03-1977", "ingreso": 0.0, "legal_person": false, "age": 64, "nivel_educativo": "4"}\n{"id": 1621, "sexo": "F", "fecha_alta": "27-05-1963", "ingreso": 1047.8510262517502, "legal_person": false, "age": 78, "nivel_educativo": "2"}\n{"id": 1622, "sexo": "M", "fecha_alta": "07-10-1988", "ingreso": 0.0, "legal_person": false, "age": 53, "nivel_educativo": "3"}\n{"id": 1624, "sexo": "M", "fecha_alta": "24-02-1971", "ingreso": 887.7649995633583, "legal_person": false, "age": 70, "nivel_educativo": "2"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 1625, "sexo": "M", "fecha_alta": "28-04-1995", "ingreso": 0.0, "legal_person": false, "age": 46, "nivel_educativo": "1"}\n{"id": 1627, "sexo": "F", "fecha_alta": "26-02-1999", "ingreso": 239.79324836329928, "legal_person": false, "age": 42, "nivel_educativo": "4"}\n{"id": 1629, "sexo": "F", "fecha_alta": "17-07-2005", "ingreso": 230.76236594245236, "legal_person": false, "age": 36, "nivel_educativo": "2"}\n{"id": 1631, "sexo": "M", "fecha_alta": "10-08-1965", "ingreso": 3484.3546713222117, "legal_person": false, "age": 76, "nivel_educativo": "4"}\n{"id": 1632, "sexo": "M", "fecha_alta": "25-06-1991", "ingreso": 0.0, "legal_person": false, "age": 50, "nivel_educativo": "3"}\n{"id": 1634, "sexo": "F", "fecha_alta": "18-09-1997", "ingreso": 957.2998997504546, "legal_person": false, "age": 44, "nivel_educativo": "3"}\n{"id": 6100, "sexo": "M", "fecha_alta": "01-12-1965", "ingreso": 0.0, "legal_person": false, "age": 76, "nivel_educativo": "3"}\n{"id": 6102, "sexo": "M", "fecha_alta": "04-06-1988", "ingreso": 334.7921951382784, "legal_person": false, "age": 53, "nivel_educativo": "1"}\n{"id": 6103, "sexo": "M", "fecha_alta": "29-04-1998", "ingreso": 2133.3458213487943, "legal_person": false, "age": 43, "nivel_educativo": "4"}\n{"id": 6104, "sexo": "F", "fecha_alta": "09-12-2002", "ingreso": 0.0, "legal_person": false, "age": 39, "nivel_educativo": "3"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 6105, "sexo": "M", "fecha_alta": "23-04-1996", "ingreso": 640.3435802581391, "legal_person": false, "age": 45, "nivel_educativo": "2"}\n{"id": 6108, "sexo": "M", "fecha_alta": "12-10-2004", "ingreso": 3.2709053781309407, "legal_person": false, "age": 37, "nivel_educativo": "2"}\n{"id": 6110, "sexo": "F", "fecha_alta": "25-02-2019", "ingreso": 2788.433193324347, "legal_person": false, "age": 22, "nivel_educativo": "2"}\n{"id": 6112, "sexo": "M", "fecha_alta": "01-05-1983", "ingreso": 0.0, "legal_person": false, "age": 58, "nivel_educativo": "4"}\n{"id": 6113, "sexo": "M", "fecha_alta": "28-11-2006", "ingreso": 0.0, "legal_person": false, "age": 35, "nivel_educativo": "4"}\n{"id": 6114, "sexo": "M", "fecha_alta": "24-09-1997", "ingreso": 881.0024791680945, "legal_person": false, "age": 44, "nivel_educativo": "1"}\n{"id": 6115, "sexo": "M", "fecha_alta": "07-12-2007", "ingreso": 430.9026539656586, "legal_person": false, "age": 34, "nivel_educativo": "3"}\n{"id": 6116, "sexo": "M", "fecha_alta": "18-01-2023", "ingreso": 0.0, "legal_person": false, "age": 18, "nivel_educativo": "4"}\n{"id": 6123, "sexo": "M", "fecha_alta": "24-05-1964", "ingreso": 384.2562617751225, "legal_person": false, "age": 77, "nivel_educativo": "3"}\n{"id": 6124, "sexo": "M", "fecha_alta": "18-01-2019", "ingreso": 0.0, "legal_person": false, "age": 22, "nivel_educativo": "2"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 6125, "sexo": "M", "fecha_alta": "28-05-1988", "ingreso": 0.0, "legal_person": false, "age": 53, "nivel_educativo": "2"}\n{"id": 6126, "sexo": "F", "fecha_alta": "16-04-1988", "ingreso": 8671.455252172873, "legal_person": false, "age": 53, "nivel_educativo": "4"}\n{"id": 6128, "sexo": "M", "fecha_alta": "14-02-1966", "ingreso": 506.86018576133785, "legal_person": false, "age": 75, "nivel_educativo": "4"}\n{"id": 6130, "sexo": "M", "fecha_alta": "25-11-2011", "ingreso": 423.0007283009226, "legal_person": false, "age": 30, "nivel_educativo": "4"}\n{"id": 6131, "sexo": "M", "fecha_alta": "16-10-1999", "ingreso": 695.2941914577605, "legal_person": false, "age": 42, "nivel_educativo": "2"}\n{"id": 6132, "sexo": "M", "fecha_alta": "31-03-2003", "ingreso": 0.0, "legal_person": false, "age": 38, "nivel_educativo": "1"}\n{"id": 6133, "sexo": "F", "fecha_alta": "12-06-1993", "ingreso": 0.0, "legal_person": false, "age": 48, "nivel_educativo": "1"}\n{"id": 6134, "sexo": "F", "fecha_alta": "28-06-1997", "ingreso": 215.7210806921796, "legal_person": false, "age": 44, "nivel_educativo": "4"}\n{"id": 6137, "sexo": "M", "fecha_alta": "08-07-1982", "ingreso": 513.6341526462182, "legal_person": false, "age": 59, "nivel_educativo": "2"}\n{"id": 6138, "sexo": "F", "fecha_alta": "17-01-1991", "ingreso": 0.0, "legal_person": false, "age": 50, "nivel_educativo": "1"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 6140, "sexo": "F", "fecha_alta": "27-02-1988", "ingreso": 561.4, "legal_person": false, "age": 53, "nivel_educativo": "2"}\n{"id": 6141, "sexo": "F", "fecha_alta": "05-08-1964", "ingreso": 387.3652418440441, "legal_person": false, "age": 77, "nivel_educativo": "3"}\n{"id": 6142, "sexo": "F", "fecha_alta": "30-11-1961", "ingreso": 492.35295422481227, "legal_person": false, "age": 80, "nivel_educativo": "1"}\n{"id": 6144, "sexo": "M", "fecha_alta": "19-08-1996", "ingreso": 463.6716717227043, "legal_person": false, "age": 45, "nivel_educativo": "1"}\n{"id": 6145, "sexo": "M", "fecha_alta": "21-07-1965", "ingreso": 0.0, "legal_person": false, "age": 76, "nivel_educativo": "1"}\n{"id": 6146, "sexo": "F", "fecha_alta": "06-09-2004", "ingreso": 2919.673456178887, "legal_person": false, "age": 37, "nivel_educativo": "2"}\n{"id": 6147, "sexo": "M", "fecha_alta": "09-07-1976", "ingreso": 701.4, "legal_person": false, "age": 65, "nivel_educativo": "1"}\n{"id": 8289, "sexo": "M", "fecha_alta": "12-08-1973", "ingreso": 1741.794280559248, "legal_person": false, "age": 68, "nivel_educativo": "1"}\n{"id": 8291, "sexo": "M", "fecha_alta": "30-11-2009", "ingreso": 0.0, "legal_person": false, "age": 32, "nivel_educativo": "2"}\n{"id": 8292, "sexo": "M", "fecha_alta": "11-08-2015", "ingreso": 0.0, "legal_person": false, "age": 26, "nivel_educativo": "2"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 8294, "sexo": "M", "fecha_alta": "16-10-1990", "ingreso": 290.5, "legal_person": false, "age": 51, "nivel_educativo": "2"}\n{"id": 8296, "sexo": "F", "fecha_alta": "23-02-1981", "ingreso": 0.0, "legal_person": false, "age": 60, "nivel_educativo": "1"}\n{"id": 8297, "sexo": "F", "fecha_alta": "16-08-1997", "ingreso": 557.5990571351226, "legal_person": false, "age": 44, "nivel_educativo": "2"}\n{"id": 8299, "sexo": "F", "fecha_alta": "31-03-1963", "ingreso": 951.5508198815829, "legal_person": false, "age": 78, "nivel_educativo": "1"}\n{"id": 8300, "sexo": "F", "fecha_alta": "22-08-1982", "ingreso": 0.0, "legal_person": false, "age": 59, "nivel_educativo": "4"}\n{"id": 8301, "sexo": "M", "fecha_alta": "20-01-2000", "ingreso": 0.0, "legal_person": false, "age": 41, "nivel_educativo": "2"}\n{"id": 8302, "sexo": "F", "fecha_alta": "09-07-1965", "ingreso": 0.0, "legal_person": false, "age": 76, "nivel_educativo": "4"}\n{"id": 8305, "sexo": "M", "fecha_alta": "06-12-1996", "ingreso": 443.4384116409116, "legal_person": false, "age": 45, "nivel_educativo": "4"}\n{"id": 8307, "sexo": "F", "fecha_alta": "09-11-1972", "ingreso": 2138.340129550126, "legal_person": false, "age": 69, "nivel_educativo": "2"}\n{"id": 8308, "sexo": "M", "fecha_alta": "16-06-1975", "ingreso": 3780.1754048254506, "legal_person": false, "age": 66, "nivel_educativo": "3"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id":
564.4321110739572, "legal_person": false, "age": 72, "nivel_educativo": "1"}\n{"id": 11353, "sexo": "F", "fecha_alta": "03-06-1965", "ingreso": 0.0, "legal_person": false, "age": 76, "nivel_educativo": "1"}\n{"id": 11354, "sexo": "F", "fecha_alta": "16-05-2022", "ingreso": 0.0, "legal_person": false, "age": 19, "nivel_educativo": "1"}\n{"id": 11355, "sexo": "M", "fecha_alta": "10-12-2001", "ingreso": 0.0, "legal_person": false, "age": 40, "nivel_educativo": "4"}\n{"id": 11358, "sexo": "M", "fecha_alta": "19-02-2018", "ingreso": 0.0, "legal_person": false, "age": 23, "nivel_educativo": "2"}\n{"id": 11359, "sexo": "F", "fecha_alta": "21-03-1972", "ingreso": 515.2, "legal_person": false, "age": 69, "nivel_educativo": "2"}\n{"id": 11362, "sexo": "F", "fecha_alta": "16-07-2010", "ingreso": 0.0, "legal_person": false, "age": 31, "nivel_educativo": "3"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 11363, "sexo": "F", "fecha_alta": "05-03-1993", "ingreso": 0.0, "legal_person": false, "age": 48, "nivel_educativo": "2"}\n{"id": 11364, "sexo": "M", "fecha_alta": "06-04-1974", "ingreso": 280.0, "legal_person": false, "age": 67, "nivel_educativo": "4"}\n{"id": 11365, "sexo": "M", "fecha_alta": "14-03-1995", "ingreso": 423.15715030130974, "legal_person": false, "age": 46, "nivel_educativo": "1"}\n{"id": 11366, "sexo": "F", "fecha_alta": "19-05-1966", "ingreso": 397.3875096244594, "legal_person": false, "age": 75, "nivel_educativo": "2"}\n{"id": 11368, "sexo": "M", "fecha_alta": "31-03-2016", "ingreso": 301.3939657800386, "legal_person": false, "age": 25, "nivel_educativo": "1"}\n{"id": 11369, "sexo": "M", "fecha_alta": "16-06-2018", "ingreso": 0.0, "legal_person": false, "age": 23, "nivel_educativo": "3"}\n{"id": 11370, "sexo": "M", "fecha_alta": "14-02-2020", "ingreso": 0.0, "legal_person": false, "age": 21, "nivel_educativo": "1"}\n{"id": 11373, "sexo": "M", "fecha_alta": "14-06-1974", "ingreso": 0.0, "legal_person": false, "age": 67, "nivel_educativo": "2"}\n{"id": 11375, "sexo": "M", "fecha_alta": "19-03-1995", "ingreso": 365.0, "legal_person": false, "age": 46, "nivel_educativo": "4"}\n{"id": 11376, "sexo": "M", "fecha_alta": "22-02-2000", "ingreso": 0.0, "legal_person": false, "age": 41, "nivel_educativo": "1"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 13881, "sexo": "M", "fecha_alta": "04-10-2013", "ingreso": 0.0, "legal_person": false, "age": 28, "nivel_educativo": "3"}\n{"id": 13882, "sexo": "F", "fecha_alta": "02-04-2013", "ingreso": 0.0, "legal_person": false, "age": 28, "nivel_educativo": "4"}\n{"id": 13883, "sexo": "M", "fecha_alta": "27-07-2001", "ingreso": 0.0, "legal_person": false, "age": 40, "nivel_educativo": "3"}\n{"id": 13884, "sexo": "M", "fecha_alta": "03-02-2008", "ingreso": 0.0, "legal_person": false, "age": 33, "nivel_educativo": "1"}\n{"id": 13885, "sexo": "M", "fecha_alta": "04-05-2012", "ingreso": 0.0, "legal_person": false, "age": 29, "nivel_educativo": "4"}\n{"id": 13887, "sexo": "M", "fecha_alta": "11-08-2009", "ingreso": 0.0, "legal_person": false, "age": 32, "nivel_educativo": "4"}\n{"id": 13888, "sexo": "F", "fecha_alta": "12-08-1982", "ingreso": 0.0, "legal_person": false, "age": 59, "nivel_educativo": "2"}\n{"id": 13890, "sexo": "M", "fecha_alta": "16-12-1966", "ingreso": 1050.0, "legal_person": false, "age": 75, "nivel_educativo": "3"}\n{"id": 13892, "sexo": "M", "fecha_alta": "25-06-2015", "ingreso": 0.0, "legal_person": false, "age": 26, "nivel_educativo": "4"}\n{"id": 13893, "sexo": "F", "fecha_alta": "12-05-2001", "ingreso": 0.0, "legal_person": false, "age": 40, "nivel_educativo": "4"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 13896, "sexo": "M", "fecha_alta": "19-10-1973", "ingreso": 0.0, "legal_person": false, "age": 68, "nivel_educativo": "4"}\n{"id": 13897, "sexo": "M", "fecha_alta": "14-02-1986", "ingreso": 48.13476634223343, "legal_person": false, "age": 55, "nivel_educativo": "4"}\n{"id": 13898, "sexo": "M", "fecha_alta": "19-10-1985", "ingreso": 0.0, "legal_person": false, "age": 56, "nivel_educativo": "4"}\n{"id": 13900, "sexo": "F", "fecha_alta": "09-12-2008", "ingreso": 0.0, "legal_person": false, "age": 33, "nivel_educativo": "1"}\n{"id": 13902, "sexo": "M", "fecha_alta": "07-02-1960", "ingreso": 0.0, "legal_person": false, "age": 81, "nivel_educativo": "4"}\n{"id": 13903, "sexo": "F", "fecha_alta": "09-03-1999", "ingreso": 0.0, "legal_person": false, "age": 42, "nivel_educativo": "1"}\n{"id": 13905, "sexo": "M", "fecha_alta": "07-03-1996", "ingreso": 810.826087613375, "legal_person": false, "age": 45, "nivel_educativo": "1"}\n{"id": 13906, "sexo": "M", "fecha_alta": "07-12-1997", "ingreso": 1382.6068519384398, "legal_person": false, "age": 44, "nivel_educativo": "4"}\n{"id": 13907, "sexo": "F", "fecha_alta": "16-09-1977", "ingreso": 0.0, "legal_person": false, "age": 64, "nivel_educativo": "2"}\n{"id": 13908, "sexo": "M", "fecha_alta": "26-02-1998", "ingreso": 0.0, "legal_person": false, "age": 43, "nivel_educativo": "3"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 13909, "sexo": "M", "fecha_alta": "29-10-1970", "ingreso": 0.0, "legal_person": false, "age": 71, "nivel_educativo": "2"}\n{"id": 13915, "sexo": "F", "fecha_alta": "29-03-2013", "ingreso": 0.0, "legal_person": false, "age": 28, "nivel_educativo": "4"}\n{"id": 13916, "sexo": "M", "fecha_alta": "23-07-2003", "ingreso": 0.0, "legal_person": false, "age": 38, "nivel_educativo": "2"}\n{"id": 13917, "sexo": "M", "fecha_alta": "22-01-2018", "ingreso": 0.0, "legal_person": false, "age": 23, "nivel_educativo": "3"}\n{"id": 13919, "sexo": "F", "fecha_alta": "07-04-2013", "ingreso": 0.0, "legal_person": false, "age": 28, "nivel_educativo": "3"}\n{"id": 13920, "sexo": "M", "fecha_alta": "29-01-2001", "ingreso": 0.0, "legal_person": false, "age": 40, "nivel_educativo": "2"}\n{"id": 13922, "sexo": "M", "fecha_alta": "03-05-2001", "ingreso": 0.0, "legal_person": false, "age": 40, "nivel_educativo": "3"}\n{"id": 13924, "sexo": "F", "fecha_alta": "19-03-1995", "ingreso": 176.7019189800807, "legal_person": false, "age": 46, "nivel_educativo": "2"}\n{"id": 13925, "sexo": "F", "fecha_alta": "20-10-1989", "ingreso": 0.0, "legal_person": false, "age": 52, "nivel_educativo": "2"}\n{"id": 13926, "sexo": "M", "fecha_alta": "17-05-2003", "ingreso": 119.37068986509348, "legal_person": false, "age": 38, "nivel_educativo": "3"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 13927, "sexo": "M", "fecha_alta": "21-08-1960", "ingreso": 0.0, "legal_person": false, "age": 81, "nivel_educativo": "4"}\n{"id": 13929, "sexo": "M", "fecha_alta": "11-12-2020", "ingreso": 0.0, "legal_person": false, "age": 21, "nivel_educativo": "2"}\n{"id": 13930, "sexo": "F", "fecha_alta": "29-05-2011", "ingreso": 0.0, "legal_person": false, "age": 30, "nivel_educativo": "1"}\n{"id": 14298, "sexo": "F", "fecha_alta": "22-03-1997", "ingreso": 0.0, "legal_person": false, "age": 44, "nivel_educativo": "1"}\n{"id": 14301, "sexo": "M", "fecha_alta": "15-08-2002", "ingreso": 1865.889541473837, "legal_person": false, "age": 39, "nivel_educativo": "3"}\n{"id": 14303, "sexo": "F", "fecha_alta": "01-07-1996", "ingreso": 0.0, "legal_person": false, "age": 45, "nivel_educativo": "4"}\n{"id": 14305, "sexo": "M", "fecha_alta": "20-03-2016", "ingreso": 0.0, "legal_person": false, "age": 25, "nivel_educativo": "1"}\n{"id": 14307, "sexo": "F", "fecha_alta": "05-02-2002", "ingreso": 0.0, "legal_person": false, "age": 39, "nivel_educativo": "2"}\n{"id": 14308, "sexo": "M", "fecha_alta": "18-08-1980", "ingreso": 0.0, "legal_person": false, "age": 61, "nivel_educativo": "2"}\n{"id": 14309, "sexo": "M", "fecha_alta": "09-04-2000", "ingreso": 602.2566390295881, "legal_person": false, "age": 41, "nivel_educativo": "2"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 14311, "sexo": "M", "fecha_alta": "29-10-1965", "ingreso": 0.0, "legal_person": false, "age": 76, "nivel_educativo": "3"}\n{"id": 14313, "sexo": "M", "fecha_alta": "13-11-1961", "ingreso": 1012.0, "legal_person": false, "age": 80, "nivel_educativo": "3"}\n{"id": 14314, "sexo": "M", "fecha_alta": "11-10-1995", "ingreso": 476.2808797711249, "legal_person": false, "age": 46, "nivel_educativo": "3"}\n{"id": 14315, "sexo": "M", "fecha_alta": "15-06-2006", "ingreso": 0.0, "legal_person": false, "age": 35, "nivel_educativo": "2"}\n{"id": 14317, "sexo": "M", "fecha_alta": "15-06-2001", "ingreso": 481.9300295826983, "legal_person": false, "age": 40, "nivel_educativo": "1"}\n{"id": 14319, "sexo": "F", "fecha_alta": "07-07-2012", "ingreso": 0.0, "legal_person": false, "age": 29, "nivel_educativo": "4"}\n{"id": 14320, "sexo": "M", "fecha_alta": "06-04-1964", "ingreso": 1949.5310766125738, "legal_person": false, "age": 77, "nivel_educativo": "3"}\n{"id": 14322,
}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 14417, "sexo": "M", "fecha_alta": "19-05-2018", "ingreso": 302.1871533745697, "legal_person": false, "age": 23, "nivel_educativo": "4"}\n{"id": 14418, "sexo": "M", "fecha_alta": "20-03-1962", "ingreso": 0.0, "legal_person": false, "age": 79, "nivel_educativo": "4"}\n{"id": 14419, "sexo": "M", "fecha_alta": "06-03-1986", "ingreso": 39.95796262574582, "legal_person": false, "age": 55, "nivel_educativo": "2"}\n{"id": 14420, "sexo": "M", "fecha_alta": "30-10-2020", "ingreso": 0.0, "legal_person": false, "age": 21, "nivel_educativo": "4"}\n{"id": 14423, "sexo": "M", "fecha_alta": "06-03-2016", "ingreso": 0.0, "legal_person": false, "age": 25, "nivel_educativo": "3"}\n{"id": 14424, "sexo": "M", "fecha_alta": "27-12-2003", "ingreso": 785.2065748366939, "legal_person": false, "age": 38, "nivel_educativo": "3"}\n{"id": 14427, "sexo": "M", "fecha_alta": "01-03-1987", "ingreso": 0.0, "legal_person": false, "age": 54, "nivel_educativo": "3"}\n{"id": 14428, "sexo": "F", "fecha_alta": "24-04-1974", "ingreso": 0.0, "legal_person": false, "age": 67, "nivel_educativo": "2"}\n{"id": 14429, "sexo": "M", "fecha_alta": "22-06-2013", "ingreso": 0.0, "legal_person": false, "age": 28, "nivel_educativo": "4"}\n{"id": 14430, "sexo": "M", "fecha_alta": "14-03-1994", "ingreso": 1086.3593899130335, "legal_person": false, "age": 47, "nivel_educativo": "4"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 14435, "sexo": "M", "fecha_alta": "16-02-1991", "ingreso": 384.25950812641224, "legal_person": false, "age": 50, "nivel_educativo": "4"}\n{"id": 14437, "sexo": "M", "fecha_alta": "20-08-1967", "ingreso": 2143.789272527244, "legal_person": false, "age": 74, "nivel_educativo": "4"}\n{"id": 14438, "sexo": "M", "fecha_alta": "14-04-1988", "ingreso": 0.0, "legal_person": false, "age": 53, "nivel_educativo": "1"}\n{"id": 14439, "sexo": "F", "fecha_alta": "13-02-2015", "ingreso": 152.7362013533649, "legal_person": false, "age": 26, "nivel_educativo": "1"}\n{"id": 14440, "sexo": "F", "fecha_alta": "30-06-1960", "ingreso": 0.0, "legal_person": false, "age": 81, "nivel_educativo": "1"}\n{"id": 14441, "sexo": "M", "fecha_alta": "10-05-1987", "ingreso": 0.0, "legal_person": false, "age": 54, "nivel_educativo": "3"}\n{"id": 14442, "sexo": "M", "fecha_alta": "20-06-1968", "ingreso": 410.74738599228607, "legal_person": false, "age": 73, "nivel_educativo": "4"}\n{"id": 14443, "sexo": "M", "fecha_alta": "09-09-1983", "ingreso": 0.0, "legal_person": false, "age": 58, "nivel_educativo": "1"}\n{"id": 14445, "sexo": "F", "fecha_alta": "26-08-1973", "ingreso": 256.43075033448406, "legal_person": false, "age": 68, "nivel_educativo": "1"}\n{"id": 14446, "sexo": "F", "fecha_alta": "15-10-2002", "ingreso": 0.0, "legal_person": false, "age": 39, "nivel_educativo": "1"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 14447, "sexo": "M", "fecha_alta": "01-03-2006", "ingreso": 0.0, "legal_person": false, "age": 35, "nivel_educativo": "1"}\n{"id": 14448, "sexo": "F", "fecha_alta": "14-01-1999", "ingreso": 1301.502202793493, "legal_person": false, "age": 42, "nivel_educativo": "3"}\n{"id": 14449, "sexo": "F", "fecha_alta": "13-09-2016", "ingreso": 0.0, "legal_person": false, "age": 25, "nivel_educativo": "3"}\n{"id": 14450, "sexo": "M", "fecha_alta": "28-07-1999", "ingreso": 0.0, "legal_person": false, "age": 42, "nivel_educativo": "2"}\n{"id": 14454, "sexo": "F", "fecha_alta": "05-03-1984", "ingreso": 0.0, "legal_person": false, "age": 57, "nivel_educativo": "4"}\n{"id": 14456, "sexo": "F", "fecha_alta": "21-07-1985", "ingreso": 0.0, "legal_person": false, "age": 56, "nivel_educativo": "3"}\n{"id": 14457, "sexo": "M", "fecha_alta": "19-07-2003", "ingreso": 0.0, "legal_person": false, "age": 38, "nivel_educativo": "3"}\n{"id": 18812, "sexo": "F", "fecha_alta": "30-11-1976", "ingreso": 1748.819787655178, "legal_person": false, "age": 65, "nivel_educativo": "3"}\n{"id": 18814, "sexo": "M", "fecha_alta": "03-07-1995", "ingreso": 0.0, "legal_person": false, "age": 46, "nivel_educativo": "4"}\n{"id": 18815, "sexo": "M", "fecha_alta": "14-08-1971", "ingreso": 0.0, "legal_person": false, "age": 70, "nivel_educativo": "4"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 18817, "sexo": "M", "fecha_alta": "02-02-2000", "ingreso": 1735.6770404279257, "legal_person": false, "age": 41, "nivel_educativo": "4"}\n{"id": 18818, "sexo": "F", "fecha_alta": "25-08-1988", "ingreso": 0.0, "legal_person": false, "age": 53, "nivel_educativo": "2"}\n{"id": 18819, "sexo": "M", "fecha_alta": "28-12-1982", "ingreso": 0.0, "legal_person": false, "age": 59, "nivel_educativo": "3"}\n{"id": 18820, "sexo": "M", "fecha_alta": "02-01-1989", "ingreso": 0.0, "legal_person": false, "age": 52, "nivel_educativo": "3"}\n{"id": 18822, "sexo": "F", "fecha_alta": "02-08-1999", "ingreso": 384.2263608061378, "legal_person": false, "age": 42, "nivel_educativo": "2"}\n{"id": 18823, "sexo": "M", "fecha_alta": "09-03-1993", "ingreso": 0.0, "legal_person": false, "age": 48, "nivel_educativo": "2"}\n{"id": 18824, "sexo": "M", "fecha_alta": "05-03-2007", "ingreso": 385.0, "legal_person": false, "age": 34, "nivel_educativo": "2"}\n{"id": 18825, "sexo": "M", "fecha_alta": "30-06-1969", "ingreso": 3376.7195831658537, "legal_person": false, "age": 72, "nivel_educativo": "1"}\n{"id": 18827, "sexo": "F", "fecha_alta": "14-07-1968", "ingreso": 1004.6822898262556, "legal_person": false, "age": 73, "nivel_educativo": "1"}\n{"id": 18828, "sexo": "M", "fecha_alta": "13-10-1967", "ingreso": 771.2873301923479, "legal_person": false, "age": 74, "nivel_educativo": "3"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id":
"nivel_educativo": "3"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 19112, "sexo": "M", "fecha_alta": "04-05-2002", "ingreso": 0.0, "legal_person": false, "age": 39, "nivel_educativo": "4"}\n{"id": 19113, "sexo": "M", "fecha_alta": "11-07-1974", "ingreso": 0.0, "legal_person": false, "age": 67, "nivel_educativo": "3"}\n{"id": 19114, "sexo": "M", "fecha_alta": "05-01-1969", "ingreso": 0.0, "legal_person": false, "age": 72, "nivel_educativo": "2"}\n{"id": 19115, "sexo": "M", "fecha_alta": "02-07-1961", "ingreso": 0.0, "legal_person": false, "age": 80, "nivel_educativo": "1"}\n{"id": 19119, "sexo": "M", "fecha_alta": "01-09-1970", "ingreso": 949.8216375454177, "legal_person": false, "age": 71, "nivel_educativo": "1"}\n{"id": 19120, "sexo": "M", "fecha_alta": "11-04-1975", "ingreso": 383.7387140199909, "legal_person": false, "age": 66, "nivel_educativo": "4"}\n{"id": 19121, "sexo": "F", "fecha_alta": "17-05-2004", "ingreso": 384.6934929953962, "legal_person": false, "age": 37, "nivel_educativo": "3"}\n{"id": 19123, "sexo": "M", "fecha_alta": "15-08-2009", "ingreso": 0.0, "legal_person": false, "age": 32, "nivel_educativo": "3"}\n{"id": 19124, "sexo": "M", "fecha_alta": "01-01-1997", "ingreso": 0.0, "legal_person": false, "age": 44, "nivel_educativo": "2"}\n{"id": 19125, "sexo": "M", "fecha_alta": "21-02-1996", "ingreso": 0.0, "legal_person": false, "age": 45, "nivel_educativo": "4"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 19126, "sexo": "F", "fecha_alta": "12-04-1966", "ingreso": 0.0, "legal_person": false, "age": 75, "nivel_educativo": "4"}\n{"id": 19127, "sexo": "M", "fecha_alta": "18-10-2009", "ingreso": 0.0, "legal_person": false, "age": 32, "nivel_educativo": "1"}\n{"id": 19128, "sexo": "F", "fecha_alta": "02-12-1999", "ingreso": 0.0, "legal_person": false, "age": 42, "nivel_educativo": "3"}\n{"id": 19129, "sexo": "M", "fecha_alta": "14-03-2010", "ingreso": 568.0869056964845, "legal_person": false, "age": 31, "nivel_educativo": "4"}\n{"id": 19130, "sexo": "M", "fecha_alta": "31-05-1964", "ingreso": 0.0, "legal_person": false, "age": 77, "nivel_educativo": "4"}\n{"id": 19133, "sexo": "M", "fecha_alta": "29-01-1983", "ingreso": 621.0498901314619, "legal_person": false, "age": 58, "nivel_educativo": "1"}\n{"id": 19134, "sexo": "F", "fecha_alta": "20-11-2013", "ingreso": 224.5403515117016, "legal_person": false, "age": 28, "nivel_educativo": "3"}\n{"id": 19135, "sexo": "M", "fecha_alta": "20-12-1969", "ingreso": 289.0, "legal_person": false, "age": 72, "nivel_educativo": "1"}\n{"id": 19137, "sexo": "F", "fecha_alta": "18-02-2005", "ingreso": 305.0, "legal_person": false, "age": 36, "nivel_educativo": "3"}\n{"id": 19138, "sexo": "M", "fecha_alta": "25-10-2013", "ingreso": 0.0, "legal_person": false, "age": 28, "nivel_educativo": "1"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 19139, "sexo": "F", "fecha_alta": "07-11-1966", "ingreso": 0.0, "legal_person": false, "age": 75, "nivel_educativo": "2"}\n{"id": 19140, "sexo": "M", "fecha_alta": "18-01-2023", "ingreso": 0.0, "legal_person": false, "age": 18, "nivel_educativo": "1"}\n{"id": 19141, "sexo": "M", "fecha_alta": "13-01-2001", "ingreso": 0.0, "legal_person": false, "age": 40, "nivel_educativo": "1"}\n{"id": 19142, "sexo": "F", "fecha_alta": "12-01-1976", "ingreso": 0.0, "legal_person": false, "age": 65, "nivel_educativo": "4"}\n{"id": 19143, "sexo": "F", "fecha_alta": "16-06-1980", "ingreso": 0.0, "legal_person": false, "age": 61, "nivel_educativo": "3"}\n{"id": 19144, "sexo": "M", "fecha_alta": "13-03-2014", "ingreso": 0.0, "legal_person": false, "age": 27, "nivel_educativo": "2"}\n{"id": 19147, "sexo": "F", "fecha_alta": "19-02-2017", "ingreso": 384.3897789933441, "legal_person": false, "age": 24, "nivel_educativo": "3"}\n{"id": 19148, "sexo": "F", "fecha_alta": "23-12-1998", "ingreso": 0.0, "legal_person": false, "age": 43, "nivel_educativo": "2"}\n{"id": 19149, "sexo": "M", "fecha_alta": "21-06-1983", "ingreso": 4.20074275687648, "legal_person": false, "age": 58, "nivel_educativo": "2"}\n{"id": 19150, "sexo": "F", "fecha_alta": "02-06-1960", "ingreso": 0.0, "legal_person": false, "age": 81, "nivel_educativo": "3"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 19153, "sexo": "M", "fecha_alta": "04-09-1972", "ingreso": 404.0, "legal_person": false, "age": 69, "nivel_educativo": "1"}\n{"id": 19154, "sexo": "M", "fecha_alta": "16-11-1973", "ingreso": 416.3683704314389, "legal_person": false, "age": 68, "nivel_educativo": "4"}\n{"id": 19155, "sexo": "M", "fecha_alta": "06-05-1991", "ingreso": 176.60430342308064, "legal_person": false, "age": 50, "nivel_educativo": "2"}\n{"id": 19156, "sexo": "M", "fecha_alta": "07-09-2011", "ingreso": 0.0, "legal_person": false, "age": 30, "nivel_educativo": "3"}\n{"id": 19480, "sexo": "M", "fecha_alta": "16-09-1978", "ingreso": 333.1365273353611, "legal_person": false, "age": 63, "nivel_educativo": "4"}\n{"id": 19481, "sexo": "M", "fecha_alta": "30-09-1980", "ingreso": 0.0, "legal_person": false, "age": 61, "nivel_educativo": "1"}\n{"id": 19482, "sexo": "M", "fecha_alta": "13-08-2007", "ingreso": 0.0, "legal_person": false, "age": 34, "nivel_educativo": "1"}\n{"id": 19485, "sexo": "M", "fecha_alta": "01-11-2006", "ingreso": 948.5, "legal_person": false, "age": 35, "nivel_educativo": "2"}\n{"id": 19486, "sexo": "M", "fecha_alta": "15-06-2014", "ingreso": 390.1986027908302, "legal_person": false, "age": 27, "nivel_educativo": "3"}\n{"id": 19488, "sexo": "F", "fecha_alta": "03-08-2011", "ingreso": 0.0, "legal_person": false, "age": 30, "nivel_educativo": "3"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 19489, "sexo": "F", "fecha_alta": "13-11-2012", "ingreso": 0.0, "legal_person": false, "age": 29, "nivel_educativo": "1"}\n{"id": 19490, "sexo": "F", "fecha_alta": "02-03-2006", "ingreso": 0.0, "legal_person": false, "age": 35, "nivel_educativo": "4"}\n{"id": 19492, "sexo": "M", "fecha_alta": "30-05-1992", "ingreso": 0.0, "legal_person": false, "age": 49, "nivel_educativo": "3"}\n{"id": 19495, "sexo": "F", "fecha_alta": "01-01-1984", "ingreso": 384.9466849018922, "legal_person": false, "age": 57, "nivel_educativo": "4"}\n{"id": 19497, "sexo": "F", "fecha_alta": "18-12-2019", "ingreso": 0.0, "legal_person": false, "age": 22, "nivel_educativo": "3"}\n{"id": 19499, "sexo": "F", "fecha_alta": "06-07-1995", "ingreso": 0.0, "legal_person": false, "age": 46, "nivel_educativo": "2"}\n{"id": 19500, "sexo": "M", "fecha_alta": "12-12-1982", "ingreso": 0.0, "legal_person": false, "age": 59, "nivel_educativo": "3"}\n{"id": 19503, "sexo": "M", "fecha_alta": "19-05-1986", "ingreso": 0.0, "legal_person": false, "age": 55, "nivel_educativo": "4"}\n{"id": 19504, "sexo": "F", "fecha_alta": "22-03-1985", "ingreso": 0.0, "legal_person": false, "age": 56, "nivel_educativo": "3"}\n{"id": 19506, "sexo": "M", "fecha_alta": "14-05-1992", "ingreso": 283.1000911751065, "legal_person": false, "age": 49, "nivel_educativo": "2"}'
# Mensaje confirmado.
# ...
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 45185, "sexo": "F", "fecha_alta": "28-05-1988", "ingreso": 108.74971132760521, "legal_person": false, "age": 53, "nivel_educativo": "1"}\n{"id": 45186, "sexo": "F", "fecha_alta": "17-04-1972", "ingreso": 2335.655515429153, "legal_person": false, "age": 69, "nivel_educativo": "2"}\n{"id": 45187, "sexo": "M", "fecha_alta": "29-08-1999", "ingreso": 3499.685082403602, "legal_person": false, "age": 42, "nivel_educativo": "4"}\n{"id": 45188, "sexo": "F", "fecha_alta": "04-08-1994", "ingreso": 0.0, "legal_person": false, "age": 47, "nivel_educativo": "3"}\n{"id": 45190, "sexo": "M", "fecha_alta": "12-04-1999", "ingreso": 332.6236391707713, "legal_person": false, "age": 42, "nivel_educativo": "1"}\n{"id": 45192, "sexo": "M", "fecha_alta": "06-07-2014", "ingreso": 4216.076389137266, "legal_person": false, "age": 27, "nivel_educativo": "4"}\n{"id": 45194, "sexo": "F", "fecha_alta": "27-01-2008", "ingreso": 9083.368017607123, "legal_person": false, "age": 33, "nivel_educativo": "2"}\n{"id": 45197, "sexo": "F", "fecha_alta": "13-08-2021", "ingreso": 0.0, "legal_person": false, "age": 20, "nivel_educativo": "3"}\n{"id": 45198, "sexo": "F", "fecha_alta": "23-04-2014", "ingreso": 0.0, "legal_person": false, "age": 27, "nivel_educativo": "3"}\n{"id": 45199, "sexo": "M", "fecha_alta": "15-04-1983", "ingreso": 388.1182906893252, "legal_person": false, "age": 58, "nivel_educativo": "2"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 45201, "sexo": "F", "fecha_alta": "15-09-1974", "ingreso": 1049.5523389001257, "legal_person": false, "age": 67, "nivel_educativo": "4"}\n{"id": 45203, "sexo": "M", "fecha_alta": "30-05-1966", "ingreso": 0.0, "legal_person": false, "age": 75, "nivel_educativo": "3"}\n{"id": 45208, "sexo": "F", "fecha_alta": "30-11-2020", "ingreso": 481.7399860425243, "legal_person": false, "age": 21, "nivel_educativo": "4"}\n{"id": 45210, "sexo": "M", "fecha_alta": "23-06-1978", "ingreso": 559.2559599313076, "legal_person": false, "age": 63, "nivel_educativo": "1"}\n{"id": 45213, "sexo": "M", "fecha_alta": "17-10-1984", "ingreso": 471.0, "legal_person": false, "age": 57, "nivel_educativo": "3"}\n{"id": 45214, "sexo": "M", "fecha_alta": "05-02-1978", "ingreso": 380.6461294674952, "legal_person": false, "age": 63, "nivel_educativo": "3"}\n{"id": 45215, "sexo": "F", "fecha_alta": "09-02-1976", "ingreso": 0.0, "legal_person": false, "age": 65, "nivel_educativo": "4"}\n{"id": 45217, "sexo": "F", "fecha_alta": "13-06-1979", "ingreso": 0.0, "legal_person": false, "age": 62, "nivel_educativo": "4"}\n{"id": 45218, "sexo": "M", "fecha_alta": "15-07-1978", "ingreso": 1753.5722870040547, "legal_person": false, "age": 63, "nivel_educativo": "3"}\n{"id": 45219, "sexo": "M", "fecha_alta": "01-05-1994", "ingreso": 0.0, "legal_person": false, "age": 47, "nivel_educativo": "1"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 45220, "sexo": "M", "fecha_alta": "21-08-2012", "ingreso": 1093.1021488776214, "legal_person": false, "age": 29, "nivel_educativo": "2"}\n{"id": 45221, "sexo": "F", "fecha_alta": "16-05-1993", "ingreso": 114.02922984351311, "legal_person": false, "age": 48, "nivel_educativo": "1"}\n{"id": 45222, "sexo": "M", "fecha_alta": "12-12-1968", "ingreso": 204.09717722658525, "legal_person": false, "age": 73, "nivel_educativo": "3"}\n{"id": 45223, "sexo": "M", "fecha_alta": "14-01-1968", "ingreso": 819.83344879531, "legal_person": false, "age": 73, "nivel_educativo": "2"}\n{"id": 46086, "sexo": "F", "fecha_alta": "09-11-2002", "ingreso": 544.9859922876868, "legal_person": false, "age": 39, "nivel_educativo": "2"}\n{"id": 46087, "sexo": "M", "fecha_alta": "24-12-1975", "ingreso": 510.9707121565301, "legal_person": false, "age": 66, "nivel_educativo": "2"}\n{"id": 46095, "sexo": "F", "fecha_alta": "18-07-2003", "ingreso": 0.0, "legal_person": false, "age": 38, "nivel_educativo": "2"}\n{"id": 46096, "sexo": "M", "fecha_alta": "06-09-2012", "ingreso": 0.0, "legal_person": false, "age": 29, "nivel_educativo": "2"}\n{"id": 46097, "sexo": "M", "fecha_alta": "17-12-1965", "ingreso": 192.98276579468623, "legal_person": false, "age": 76, "nivel_educativo": "1"}\n{"id": 46098, "sexo": "M", "fecha_alta": "26-12-2021", "ingreso": 158.87848446666445, "legal_person": false, "age": 20, "nivel_educativo": "4"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 46099, "sexo": "M", "fecha_alta": "27-05-1998", "ingreso": 1189.0535224638638, "legal_person": false, "age": 43, "nivel_educativo": "4"}\n{"id": 46101, "sexo": "M", "fecha_alta": "11-11-2001", "ingreso": 177.88096602297162, "legal_person": false, "age": 40, "nivel_educativo": "4"}\n{"id": 46103, "sexo": "F", "fecha_alta": "22-11-1965", "ingreso": 0.0, "legal_person": false, "age": 76, "nivel_educativo": "4"}\n{"id": 46104, "sexo": "M", "fecha_alta": "31-08-1986", "ingreso": 599.1957793897723, "legal_person": false, "age": 55, "nivel_educativo": "4"}\n{"id": 46105, "sexo": "M", "fecha_alta": "28-03-2012", "ingreso": 1642.33734770599, "legal_person": false, "age": 29, "nivel_educativo": "4"}\n{"id": 46106, "sexo": "F", "fecha_alta": "16-05-2014", "ingreso": 0.0, "legal_person": false, "age": 27, "nivel_educativo": "2"}\n{"id": 46107, "sexo": "F", "fecha_alta": "27-09-2011", "ingreso": 0.0, "legal_person": false, "age": 30, "nivel_educativo": "1"}\n{"id": 46109, "sexo": "F", "fecha_alta": "22-07-1965", "ingreso": 663.1841096157082, "legal_person": false, "age": 76, "nivel_educativo": "3"}\n{"id": 46110, "sexo": "F", "fecha_alta": "21-02-2018", "ingreso": 0.0, "legal_person": false, "age": 23, "nivel_educativo": "3"}\n{"id": 46111, "sexo": "M", "fecha_alta": "26-05-1980", "ingreso": 0.0, "legal_person": false, "age": 61, "nivel_educativo": "4"}'
# Mensaje confirmado.
# Mensaje recibido: b'{"id": 46115, "sexo": "M", "fecha_alta": "26-12-1975", "ingreso": 5626.686725118627, "legal_person": false, "age": 66, "nivel_educativo": "3"}\n{"id": 46116, "sexo": "M", "fecha_alta": "15-01-1968", "ingreso": 189.24500157590552, "legal_person": false, "age": 73, "nivel_educativo": "2"}\n{"id": 46117, "sexo": "M", "fecha_alta": "26-08-2015", "ingreso": 1367.450482988159, "legal_person": false, "age": 26, "nivel_educativo": "3"}\n{"id": 46118, "sexo": "F", "fecha_alta": "26-06-1960", "ingreso": 0.0, "legal_person": false, "age": 81, "nivel_educativo": "2"}\n{"id": 46119, "sexo": "M", "fecha_alta": "16-09-1985", "ingreso": 0.0, "legal_person": false, "age": 56, "nivel_educativo": "1"}\n{"id": 46120, "sexo": "F", "fecha_alta": "09-04-1960", "ingreso": 0.0, "legal_person": false, "age": 81, "nivel_educativo": "3"}\n{"id": 46122, "sexo": "F", "fecha_alta": "25-10-1960", "ingreso": 209.06190946942863, "legal_person": false, "age": 81, "nivel_educativo": "2"}\n{"id": 46124, "sexo": "M", "fecha_alta": "16-01-1973", "ingreso": 0.0, "legal_person": false, "age": 68, "nivel_educativo": "3"}\n{"id": 46126, "sexo": "M", "fecha_alta": "24-03-2010", "ingreso": 0.0, "legal_person": false, "age": 31, "nivel_educativo": "3"}\n{"id": 46127, "sexo": "M", "fecha_alta": "01-05-2005", "ingreso": 425.2636221668694, "legal_person": false, "age": 36, "nivel_educativo": "4"}'
# Mensaje confirmado.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c8b5ff7e9af3> in <cell line: 12>()
#      23         break
#      24     # Llamar a la función de Pub/Sub
# ---> 25     process_clientes(project_id, topic_id, subscription_name, df_clientes)
#      26     offset += tam_proceso
#      27     sleep(1)
#
# <ipython-input-6-6b2ea17c5e8e> in process_clientes(project_id, topic_id, subscription_name, df, batch_size)
#       9 # Función para mandar los mensajes de Pub/Sub a Cloud Function
#      10 def process_clientes(project_id, topic_id, subscription_name, df=None, batch_size=10):
# ---> 11     publisher = pubsub_v1.PublisherClient() # publicador
#      12     subscriber = pubsub_v1.SubscriberClient() # suscriptor
#      13
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/pubsub_v1/publisher/client.py in __init__(self, batch_settings, publisher_options, **kwargs)
#     137         # Add the metrics headers, and instantiate the underlying GAPIC
#     138         # client.
# --> 139         super().__init__(**kwargs)
#     140         self._target = self._transport._host
#     141         self._batch_class = thread.Batch
#
# /usr/local/lib/python3.10/dist-packages/google/pubsub_v1/services/publisher/client.py in __init__(self, credentials, transport, client_options, client_info)
#     490                 Transport = functools.partial(Transport, channel=channel)
#     491
# --> 492             self._transport = Transport(
#     493                 credentials=credentials,
#     494                 credentials_file=client_options.credentials_file,
#
# /usr/local/lib/python3.10/dist-packages/google/pubsub_v1/services/publisher/transports/grpc.py in __init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     151
#     152         # The base transport sets the host, credentials and scopes
# --> 153         super().__init__(
#     154             host=host,
#     155             credentials=credentials,
#
# /usr/local/lib/python3.10/dist-packages/google/pubsub_v1/services/publisher/transports/base.py in __init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#     102             )
#     103         elif credentials is None:
# --> 104             credentials, _ = google.auth.default(
#     105                 **scopes_kwargs, quota_project_id=quota_project_id
#     106             )
#
# /usr/local/lib/python3.10/dist-packages/google/auth/_default.py in default(scopes, request, quota_project_id, default_scopes)
#     613
#     614     for checker in checkers:
# --> 615         credentials, project_id = checker()
#     616         if credentials is not None:
#     617             credentials = with_scopes_if_required(
#
# /usr/local/lib/python3.10/dist-packages/google/auth/_default.py in <lambda>()
#     606         # safely set on the returned credentials since requires_scopes will
#     607         # guard against setting scopes on user credentials.
# --> 608         lambda: _get_explicit_environ_credentials(quota_project_id=quota_project_id),
#     609         lambda: _get_gcloud_sdk_credentials(quota_project_id=quota_project_id),
#     610         _get_gae_credentials,
#
# /usr/local/lib/python3.10/dist-packages/google/auth/_default.py in _get_explicit_environ_credentials(quota_project_id)
#     226
#     227     if explicit_file is not None:
# --> 228         credentials, project_id = load_credentials_from_file(
#     229             os.environ[environment_vars.CREDENTIALS], quota_project_id=quota_project_id
#     230         )
#
# /usr/local/lib/python3.10/dist-packages/google/auth/_default.py in load_credentials_from_file(filename, scopes, default_scopes, quota_project_id, request)
#     126             )
#     127             six.raise_from(new_exc, caught_exc)
# --> 128     return _load_credentials_from_info(
#     129         filename, info, scopes, default_scopes, quota_project_id, request
#     130     )
#
# /usr/local/lib/python3.10/dist-packages/google/auth/_default.py in _load_credentials_from_info(filename, info, scopes, default_scopes, quota_project_id, request)
#     144
#     145     elif credential_type == _SERVICE_ACCOUNT_TYPE:
# --> 146         credentials, project_id = _get_service_account_credentials(
#     147             filename, info, scopes, default_scopes
#     148         )
#
# /usr/local/lib/python3.10/dist-packages/google/auth/_default.py in _get_service_account_credentials(filename, info, scopes, default_scopes)
#     405
#     406     try:
# --> 407         credentials = service_account.Credentials.from_service_account_info(
#     408             info, scopes=scopes, default_scopes=default_scopes
#     409         )
#
# /usr/local/lib/python3.10/dist-packages/google/oauth2/service_account.py in from_service_account_info(cls, info, **kwargs)
#     222             ValueError: If the info is not in the expected format.
#     223         """
# --> 224         signer = _service_account_info.from_dict(
#     225             info, require=["client_email", "token_uri"]
#     226         )
#
# /usr/local/lib/python3.10/dist-packages/google/auth/_service_account_info.py in from_dict(data, require, use_rsa_signer)
#      57     # Create a signer.
#      58     if use_rsa_signer:
# ---> 59         signer = crypt.RSASigner.from_service_account_info(data)
#      60     else:
#      61         signer = crypt.ES256Signer.from_service_account_info(data)
#
# /usr/local/lib/python3.10/dist-packages/google/auth/crypt/base.py in from_service_account_info(cls, info)
#     112             )
#     113
# --> 114         return cls.from_string(
#     115             info[_JSON_FILE_PRIVATE_KEY], info.get(_JSON_FILE_PRIVATE_KEY_ID)
#     116         )
#
# /usr/local/lib/python3.10/dist-packages/google/auth/crypt/_cryptography_rsa.py in from_string(cls, key, key_id)
#     131         """
#     132         key = _helpers.to_bytes(key)
# --> 133         private_key = serialization.load_pem_private_key(
#     134             key, password=None, backend=_BACKEND
#     135         )
#
# /usr/local/lib/python3.10/dist-packages/cryptography/hazmat/primitives/serialization/base.py in load_pem_private_key(data, password, backend, unsafe_skip_rsa_key_validation)
#      23     from cryptography.hazmat.backends.openssl.backend import backend as ossl
#      24
# ---> 25     return ossl.load_pem_private_key(
#      26         data, password, unsafe_skip_rsa_key_validation
#      27     )
#
# /usr/local/lib/python3.10/dist-packages/cryptography/hazmat/backends/openssl/backend.py in load_pem_private_key(self, data, password, unsafe_skip_rsa_key_validation)
#     745         unsafe_skip_rsa_key_validation: bool,
#     746     ) -> PrivateKeyTypes:
# --> 747         return self._load_key(
#     748             self._lib.PEM_read_bio_PrivateKey,
#     749             data,
#
# /usr/local/lib/python3.10/dist-packages/cryptography/hazmat/backends/openssl/backend.py in _load_key(self, openssl_read_func, data, password, unsafe_skip_rsa_key_validation)
#     940         ) or password is None
#     941
# --> 942         return self._evp_pkey_to_private_key(
#     943             evp_pkey, unsafe_skip_rsa_key_validation
#     944         )
#
# /usr/local/lib/python3.10/dist-packages/cryptography/hazmat/backends/openssl/backend.py in _evp_pkey_to_private_key(self, evp_pkey, unsafe_skip_rsa_key_validation)
#     519             self.openssl_assert(rsa_cdata != self._ffi.NULL)
#     520             rsa_cdata = self._ffi.gc(rsa_cdata, self._lib.RSA_free)
# --> 521             return _RSAPrivateKey(
#     522                 self,
#     523                 rsa_cdata,
#
# /usr/local/lib/python3.10/dist-packages/cryptography/hazmat/backends/openssl/rsa.py in __init__(self, backend, rsa_cdata, evp_pkey, unsafe_skip_rsa_key_validation)
#     381         # use this in production code unless you understand the consequences.
#     382         if not unsafe_skip_rsa_key_validation:
# --> 383             res = backend._lib.RSA_check_key(rsa_cdata)
#     384             if res != 1:
#     385                 errors = backend._consume_errors()
#
# KeyboardInterrupt:
